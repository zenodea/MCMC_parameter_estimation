# %%
import pandas as pd

# %%
df = pd.read_csv('../raw_data/Covid_Data/uk_covid_data.csv', sep=",")
df
# Out:
#        areaCode        areaName  areaType        date  \
# 0     K02000001  United Kingdom  overview  2023-03-27
# 1     K02000001  United Kingdom  overview  2023-03-26
# 2     K02000001  United Kingdom  overview  2023-03-25
# 3     K02000001  United Kingdom  overview  2023-03-24
# 4     K02000001  United Kingdom  overview  2023-03-23
# ...         ...             ...       ...         ...
# 1148  K02000001  United Kingdom  overview  2020-02-03
# 1149  K02000001  United Kingdom  overview  2020-02-02
# 1150  K02000001  United Kingdom  overview  2020-02-01
# 1151  K02000001  United Kingdom  overview  2020-01-31
# 1152  K02000001  United Kingdom  overview  2020-01-30
#
#       cumDailyNsoDeathsByDeathDate  cumOnsDeathsByRegistrationDate  \
# 0                              NaN                             NaN
# 1                              NaN                             NaN
# 2                              NaN                             NaN
# ...

# %%
df = df[['date','cumDailyNsoDeathsByDeathDate','cumPillarFourTestsByPublishDate']]
df = df[::-1]
df['cumDeath'] = df['cumDailyNsoDeathsByDeathDate']
df = df.rename(columns={ "cumPillarFourTestsByPublishDate": "cumCases",})

# %%
df
# Out:
#             date  cumDailyNsoDeathsByDeathDate    cumCases  cumDeath
# 1152  2020-01-30                           1.0         NaN       1.0
# 1151  2020-01-31                           1.0         NaN       1.0
# 1150  2020-02-01                           1.0         NaN       1.0
# 1149  2020-02-02                           2.0         NaN       2.0
# 1148  2020-02-03                           2.0         NaN       2.0
# ...          ...                           ...         ...       ...
# 4     2023-03-23                           NaN  18427403.0       NaN
# 3     2023-03-24                           NaN  18429305.0       NaN
# 2     2023-03-25                           NaN  18429305.0       NaN
# 1     2023-03-26                           NaN  18429305.0       NaN
# 0     2023-03-27                           NaN  18431230.0       NaN
#
# [1153 rows x 4 columns]

# %%
df.to_csv('../processed_data/cumDeathUK.csv', index=False)
