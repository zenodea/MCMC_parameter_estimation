# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats
import math

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import lognorm

# Set mean and standard deviation

mean = 0.0771
# Calculate parameters of the lognormal distribution
sigma = 0.3
mu = np.log(mean)

# Generate a set of random numbers that follow a lognormal distribution
data = np.random.lognormal(mu, sigma, 10000)

# Plot a histogram of the generated numbers
plt.hist(data, bins=50, density=True, alpha=0.6)

# Overlay a plot of the lognormal probability density function on the histogram
x = np.linspace(0, 1, 1)
pdf = lognorm.pdf(x, sigma, scale=np.exp(mu))
plt.plot(x, pdf, 'r-', lw=2)

# Set mean and standard deviation
M = 0.08984
SD = 0.02699
V = SD**2 # Variance of the lognormal distribution
sigma = np.sqrt(V)
mu = np.log(M)
# Calculate parameters of the lognormal distribution

# Generate a set of random numbers that follow a lognormal distribution
data = np.random.lognormal(mu, sigma, 10000)

# Plot a histogram of the generated numbers
plt.hist(data, bins=50, density=True, alpha=0.6)

# Overlay a plot of the lognormal probability density function on the histogram
x = np.linspace(0.1, 0, 10000)
pdf = lognorm.pdf(x, sigma, scale=np.exp(mu))
plt.plot(x, pdf, color="black", lw=2)
plt.xlim(0.04,0.11)


# Set axis labels and title
plt.xlabel('Mortality Rate')
plt.ylabel('Probability Density')
plt.title('Initial and Final Prior Belief ($\\rho$)')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import lognorm

# Set mean and standard deviation
mean =  1/8
sd = 0.1

# Calculate parameters of the lognormal distribution
sigma = 0.1
mu = np.log(mean) - 0.5 * sigma**2

# Generate a set of random numbers that follow a lognormal distribution
data = np.random.lognormal(mu, sigma, 10000)

# Plot a histogram of the generated numbers
plt.hist(data, bins=50, density=True, alpha=0.6)

# Overlay a plot of the lognormal probability density function on the histogram
x = np.linspace(0, 1, 1)
pdf = lognorm.pdf(x, sigma, scale=np.exp(mu))
plt.plot(x, pdf, 'r-', lw=2)

# Set mean and standard deviation
M = 0.12635
SD = 0.0128
V = SD**2 # Variance of the lognormal distribution
sigma = np.sqrt(V)
mu = np.log(M)
# Calculate parameters of the lognormal distribution

# Generate a set of random numbers that follow a lognormal distribution
data = np.random.lognormal(mu, sigma, 10000)

# Plot a histogram of the generated numbers
plt.hist(data, bins=50, density=True, alpha=0.6)

# Overlay a plot of the lognormal probability density function on the histogram
x = np.linspace(0.1, 0.18, 10000)
pdf = lognorm.pdf(x, sigma, scale=np.exp(mu))
plt.plot(x, pdf, color="black", lw=2)
plt.xlim(0.1,0.15)

# Set axis labels and title
plt.xlabel('Recovery Rate')
plt.ylabel('Probability Density')
plt.title('Initial and Final Prior Belief ($\gamma$)')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import lognorm

# Set mean and standard deviation
mean = 0.449
sd = 0.5

# Calculate parameters of the lognormal distribution
sigma = 0.5
mu = np.log(mean)

# Generate a set of random numbers that follow a lognormal distribution
data = np.random.lognormal(mu, sigma, 10000)

# Plot a histogram of the generated numbers
plt.hist(data, bins=50, density=True, alpha=0.6)

# Overlay a plot of the lognormal probability density function on the histogram
x = np.linspace(0, 1, 1)
pdf = lognorm.pdf(x, sigma, scale=np.exp(mu))
plt.plot(x, pdf, 'r-', lw=2)

# Set mean and standard deviation
SD = 0.03079
M = 0.28883
V = SD**2 # Variance of the lognormal distribution
sigma = np.sqrt(V)
mu = np.log(M)
# Calculate parameters of the lognormal distribution

# Generate a set of random numbers that follow a lognormal distribution
data = np.random.lognormal(mu, sigma, 10000)

# Plot a histogram of the generated numbers
plt.hist(data, bins=50, density=True, alpha=0.6)

# Overlay a plot of the lognormal probability density function on the histogram

x = np.linspace(0.1, 1, 100000)
pdf = lognorm.pdf(x, sigma, scale=np.exp(mu))
plt.plot(x, pdf, color="black", lw=2)
plt.xlim(0.2,0.6)

# Set axis labels and title
plt.xlabel('Infection Rate')
plt.ylabel('Probability Density')
plt.title('Initial and Final Prior Belief ($\\beta$)')

plt.show()
