# %%
import pandas as pd

# %%
df = pd.read_csv('../raw_data/Covid_Data/uk_covid_data.csv', sep=",")
df
# Out:
#        areaCode        areaName  areaType        date  \
# 0     K02000001  United Kingdom  overview  2023-01-13
# 1     K02000001  United Kingdom  overview  2023-01-12
# 2     K02000001  United Kingdom  overview  2023-01-11
# 3     K02000001  United Kingdom  overview  2023-01-10
# 4     K02000001  United Kingdom  overview  2023-01-09
# ...         ...             ...       ...         ...
# 1075  K02000001  United Kingdom  overview  2020-02-03
# 1076  K02000001  United Kingdom  overview  2020-02-02
# 1077  K02000001  United Kingdom  overview  2020-02-01
# 1078  K02000001  United Kingdom  overview  2020-01-31
# 1079  K02000001  United Kingdom  overview  2020-01-30
#
#       cumDailyNsoDeathsByDeathDate
# 0                           217262
# 1                           217230
# 2                           217166
# 3                           217120
# 4                           217048
# ...                            ...
# 1075                             2
# ...

# %%
df = df[['date','cumDailyNsoDeathsByDeathDate']]
df = df.iloc[::-1]
